# %%
import gym
import matplotlib.pyplot as plt
import numpy as np
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import random
from IPython.display import clear_output
from collections import deque
from tqdm.notebook import tqdm
from collections import deque

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import keras.backend as K

# tf.compat.v1.disable_eager_execution()

# %%
class DQAgent():
    def __init__(self, 
                 observation_space, 
                 action_space, 
                 gamma=0.99, 
                 lr=0.001):
        self.observation_space = observation_space
        self.action_space = action_space
        self.gamma = gamma
        self.lr = lr
        self.model = self.build_model(name='model')
        
    def build_model(self, name):
        model = keras.Sequential(name = name)
        model.add(keras.Input(shape=self.observation_space))
        model.add(keras.layers.Dense(128, activation='relu'))
        model.add(keras.layers.Dense(128, activation='relu'))
        model.add(keras.layers.Dense(128, activation='relu'))
        model.add(keras.layers.Dense(self.action_space, activation='linear'))
        
        model.compile(
            optimizer=keras.optimizers.legacy.Adam(learning_rate=self.lr),
            loss='mse'
        )
        return model
    
    def predict(self, observation):
        return self.model.predict(np.array([observation]), verbose=False)[0]
    
    def predict_action(self, observation):
        return np.argmax(self.predict(observation))
    
    def e_greedy(self, observation, e=0.1):
        if random.random() >= e:
            return self.predict_action(observation)
        return random.randint(0, self.action_space-1)
    
    def train(self, s, a, r, s_, terminated):
        q_values = self.predict(s)
        new_q = np.max(self.predict(s_))
        y = q_values
        if not terminated:
            y[a] = r + self.gamma*new_q
        else:
            y[a] = r
        self.model.fit(np.array([s]), np.array([y]), verbose=False)

# %%
env = gym.make("LunarLander-v2")
agent = DQAgent(env.observation_space.shape, env.action_space.n)

episodes = 2000
max_t = 500
e=0.05
scores = []
avgs = []

for episode in range(episodes):
    observation, _ = env.reset()
    
    score = 0
    for t in range(max_t):
        s = observation
        a = agent.e_greedy(s, e=e)
        observation, reward, terminated, _, _ = env.step(a)
        score +=  reward
        s_ = observation
        agent.train(s, a, reward, s_, terminated)
        if terminated:
            break
    scores.append(score)
    avgs.append(np.sum(scores[-50:])/len(scores[-50:]))
    print(f"episode: {episode}, e: {e}, t: {t}, score: {score : .2f}, avg score: {avgs[-1]: .2f}")
    if avgs[-1] >= 200:
        break

plt.plot(scores)
plt.plot(avgs)
plt.show()
# Out:
# episode: 0, e: 0.05, t: 88, score: -407.63, avg score: -407.63
# episode: 1, e: 0.05, t: 101, score: -361.56, avg score: -384.60
# episode: 2, e: 0.05, t: 49, score: -422.63, avg score: -397.27
# episode: 3, e: 0.05, t: 63, score: -526.63, avg score: -429.61
# episode: 4, e: 0.05, t: 61, score: -484.16, avg score: -440.52
# episode: 5, e: 0.05, t: 85, score: -755.04, avg score: -492.94
# episode: 6, e: 0.05, t: 52, score: -327.22, avg score: -469.27
# episode: 7, e: 0.05, t: 82, score: -700.90, avg score: -498.22
# episode: 8, e: 0.05, t: 77, score: -792.00, avg score: -530.86
# episode: 9, e: 0.05, t: 61, score: -562.06, avg score: -533.98
# episode: 10, e: 0.05, t: 76, score: -580.79, avg score: -538.24
# episode: 11, e: 0.05, t: 77, score: -636.13, avg score: -546.40
# episode: 12, e: 0.05, t: 66, score: -488.79, avg score: -541.96
# episode: 13, e: 0.05, t: 53, score: -490.44, avg score: -538.28
# episode: 14, e: 0.05, t: 67, score: -638.14, avg score: -544.94
# episode: 15, e: 0.05, t: 59, score: -432.99, avg score: -537.94
# episode: 16, e: 0.05, t: 115, score: -412.33, avg score: -530.55
# episode: 17, e: 0.05, t: 74, score: -146.45, avg score: -509.22
# episode: 18, e: 0.05, t: 81, score: -118.66, avg score: -488.66
# episode: 19, e: 0.05, t: 89, score: -33.33, avg score: -465.89
# episode: 20, e: 0.05, t: 88, score: -186.88, avg score: -452.61
# episode: 21, e: 0.05, t: 69, score: -57.97, avg score: -434.67
# episode: 22, e: 0.05, t: 89, score: -150.21, avg score: -422.30
# episode: 23, e: 0.05, t: 68, score: -161.83, avg score: -411.45
# episode: 24, e: 0.05, t: 118, score: -197.75, avg score: -402.90
# episode: 25, e: 0.05, t: 51, score: -108.13, avg score: -391.56
# episode: 26, e: 0.05, t: 66, score: -116.49, avg score: -381.38
# episode: 27, e: 0.05, t: 73, score: -3.81, avg score: -367.89
# episode: 28, e: 0.05, t: 116, score: -222.40, avg score: -362.87
# episode: 29, e: 0.05, t: 78, score: -133.57, avg score: -355.23
# episode: 30, e: 0.05, t: 119, score: -227.52, avg score: -351.11
# episode: 31, e: 0.05, t: 74, score: -405.85, avg score: -352.82
# episode: 32, e: 0.05, t: 80, score: -270.08, avg score: -350.31
# episode: 33, e: 0.05, t: 68, score: -132.82, avg score: -343.92
# episode: 34, e: 0.05, t: 65, score: -397.54, avg score: -345.45
# episode: 35, e: 0.05, t: 85, score: -150.69, avg score: -340.04
# episode: 36, e: 0.05, t: 60, score: -141.89, avg score: -334.68
# episode: 37, e: 0.05, t: 70, score: -174.10, avg score: -330.46
# episode: 38, e: 0.05, t: 72, score: -120.80, avg score: -325.08
# episode: 39, e: 0.05, t: 70, score: -178.49, avg score: -321.42
# episode: 40, e: 0.05, t: 83, score: -163.70, avg score: -317.57
# episode: 41, e: 0.05, t: 76, score: -151.69, avg score: -313.62
# episode: 42, e: 0.05, t: 57, score: -353.97, avg score: -314.56
# episode: 43, e: 0.05, t: 72, score: -438.92, avg score: -317.39
# episode: 44, e: 0.05, t: 85, score: -593.37, avg score: -323.52
# episode: 45, e: 0.05, t: 182, score: -918.68, avg score: -336.46
# episode: 46, e: 0.05, t: 76, score: -523.07, avg score: -340.43
# episode: 47, e: 0.05, t: 55, score: -419.24, avg score: -342.07
# episode: 48, e: 0.05, t: 87, score: -179.68, avg score: -338.76
# episode: 49, e: 0.05, t: 76, score: -100.09, avg score: -333.98
# episode: 50, e: 0.05, t: 79, score: -185.50, avg score: -329.54
# episode: 51, e: 0.05, t: 53, score: -92.52, avg score: -324.16
# episode: 52, e: 0.05, t: 52, score: -74.81, avg score: -317.20
# episode: 53, e: 0.05, t: 82, score: -305.22, avg score: -312.77
# episode: 54, e: 0.05, t: 75, score: -143.69, avg score: -305.96
# episode: 55, e: 0.05, t: 56, score: -309.12, avg score: -297.05
# episode: 56, e: 0.05, t: 102, score: -123.20, avg score: -292.97
# episode: 57, e: 0.05, t: 60, score: -489.74, avg score: -288.74
# episode: 58, e: 0.05, t: 72, score: -134.26, avg score: -275.59
# episode: 59, e: 0.05, t: 81, score: -116.26, avg score: -266.67
# episode: 60, e: 0.05, t: 61, score: -126.38, avg score: -257.58
# episode: 61, e: 0.05, t: 54, score: -99.68, avg score: -246.85
# episode: 62, e: 0.05, t: 56, score: -130.99, avg score: -239.70
# episode: 63, e: 0.05, t: 52, score: -124.59, avg score: -232.38
# episode: 64, e: 0.05, t: 55, score: -101.16, avg score: -221.64
# episode: 65, e: 0.05, t: 57, score: -134.12, avg score: -215.66
# episode: 66, e: 0.05, t: 54, score: -89.25, avg score: -209.20
# episode: 67, e: 0.05, t: 87, score: -92.25, avg score: -208.12
# episode: 68, e: 0.05, t: 77, score: -159.61, avg score: -208.94
# episode: 69, e: 0.05, t: 96, score: -131.69, avg score: -210.91
# episode: 70, e: 0.05, t: 88, score: -130.81, avg score: -209.78
# episode: 71, e: 0.05, t: 70, score: -173.46, avg score: -212.09
# episode: 72, e: 0.05, t: 68, score: -65.52, avg score: -210.40
# episode: 73, e: 0.05, t: 117, score: -284.83, avg score: -212.86
# episode: 74, e: 0.05, t: 95, score: -117.06, avg score: -211.25
# episode: 75, e: 0.05, t: 81, score: -135.84, avg score: -211.80
# episode: 76, e: 0.05, t: 66, score: -131.53, avg score: -212.10
# episode: 77, e: 0.05, t: 139, score: -260.22, avg score: -217.23
# episode: 78, e: 0.05, t: 88, score: -387.02, avg score: -220.52
# episode: 79, e: 0.05, t: 68, score: -178.71, avg score: -221.42
# episode: 80, e: 0.05, t: 61, score: -191.45, avg score: -220.70
# episode: 81, e: 0.05, t: 105, score: -258.98, avg score: -217.77
# episode: 82, e: 0.05, t: 90, score: -135.04, avg score: -215.06
# episode: 83, e: 0.05, t: 73, score: -245.77, avg score: -217.32
# episode: 84, e: 0.05, t: 89, score: -117.78, avg score: -211.73
# episode: 85, e: 0.05, t: 64, score: -94.10, avg score: -210.60
# episode: 86, e: 0.05, t: 75, score: -136.27, avg score: -210.48
# episode: 87, e: 0.05, t: 117, score: -244.59, avg score: -211.89
# episode: 88, e: 0.05, t: 52, score: -134.00, avg score: -212.16
# episode: 89, e: 0.05, t: 53, score: -109.47, avg score: -210.78
# episode: 90, e: 0.05, t: 65, score: -111.02, avg score: -209.72
# episode: 91, e: 0.05, t: 89, score: -131.58, avg score: -209.32
# episode: 92, e: 0.05, t: 90, score: -91.41, avg score: -204.07
# episode: 93, e: 0.05, t: 95, score: -149.29, avg score: -198.28
# episode: 94, e: 0.05, t: 142, score: -163.20, avg score: -189.67
# episode: 95, e: 0.05, t: 95, score: -126.49, avg score: -173.83
# episode: 96, e: 0.05, t: 57, score: -141.45, avg score: -166.20
# episode: 97, e: 0.05, t: 88, score: -128.66, avg score: -160.39
# episode: 98, e: 0.05, t: 98, score: -206.03, avg score: -160.91
# episode: 99, e: 0.05, t: 88, score: -262.11, avg score: -164.15
# episode: 100, e: 0.05, t: 75, score: -331.78, avg score: -167.08
# episode: 101, e: 0.05, t: 60, score: -198.79, avg score: -169.21
# episode: 102, e: 0.05, t: 80, score: -109.06, avg score: -169.89
# episode: 103, e: 0.05, t: 75, score: -111.96, avg score: -166.03
# episode: 104, e: 0.05, t: 56, score: -108.48, avg score: -165.32
# episode: 105, e: 0.05, t: 81, score: -118.27, avg score: -161.50
# episode: 106, e: 0.05, t: 89, score: -128.53, avg score: -161.61
# episode: 107, e: 0.05, t: 57, score: -104.37, avg score: -153.90
# episode: 108, e: 0.05, t: 240, score: -408.73, avg score: -159.39
# episode: 109, e: 0.05, t: 84, score: -131.82, avg score: -159.70
# episode: 110, e: 0.05, t: 68, score: -78.23, avg score: -158.74
# episode: 111, e: 0.05, t: 140, score: -313.68, avg score: -163.02
# episode: 112, e: 0.05, t: 73, score: -609.18, avg score: -172.58
# episode: 113, e: 0.05, t: 66, score: -594.53, avg score: -181.98
# episode: 114, e: 0.05, t: 68, score: -515.32, avg score: -190.27
# episode: 115, e: 0.05, t: 74, score: -622.22, avg score: -200.03
# episode: 116, e: 0.05, t: 87, score: -369.49, avg score: -205.63
# episode: 117, e: 0.05, t: 60, score: -150.92, avg score: -206.81
# episode: 118, e: 0.05, t: 69, score: -150.77, avg score: -206.63
# episode: 119, e: 0.05, t: 77, score: -164.43, avg score: -207.28
# episode: 120, e: 0.05, t: 78, score: -130.93, avg score: -207.29
# episode: 121, e: 0.05, t: 79, score: -221.08, avg score: -208.24
# episode: 122, e: 0.05, t: 77, score: -160.78, avg score: -210.14
# episode: 123, e: 0.05, t: 60, score: -134.85, avg score: -207.15
# episode: 124, e: 0.05, t: 85, score: -136.03, avg score: -207.52
# episode: 125, e: 0.05, t: 55, score: -118.18, avg score: -207.17
# episode: 126, e: 0.05, t: 57, score: -112.59, avg score: -206.79
# episode: 127, e: 0.05, t: 61, score: -127.96, avg score: -204.15
# episode: 128, e: 0.05, t: 62, score: -121.31, avg score: -198.83
# episode: 129, e: 0.05, t: 86, score: -144.48, avg score: -198.15
# episode: 130, e: 0.05, t: 100, score: -290.07, avg score: -200.12
# episode: 131, e: 0.05, t: 114, score: -493.33, avg score: -204.81
# episode: 132, e: 0.05, t: 154, score: -497.11, avg score: -212.05
# episode: 133, e: 0.05, t: 95, score: -234.31, avg score: -211.82
# episode: 134, e: 0.05, t: 89, score: -4.86, avg score: -209.56
# episode: 135, e: 0.05, t: 108, score: -226.69, avg score: -212.21
# episode: 136, e: 0.05, t: 76, score: -203.35, avg score: -213.56
# episode: 137, e: 0.05, t: 115, score: -306.16, avg score: -214.79
# episode: 138, e: 0.05, t: 68, score: -214.93, avg score: -216.41
# episode: 139, e: 0.05, t: 112, score: -223.76, avg score: -218.69
# episode: 140, e: 0.05, t: 56, score: -137.47, avg score: -219.22
# episode: 141, e: 0.05, t: 53, score: -137.87, avg score: -219.35
# episode: 142, e: 0.05, t: 74, score: -180.58, avg score: -221.13
# episode: 143, e: 0.05, t: 89, score: -160.86, avg score: -221.36
# episode: 144, e: 0.05, t: 55, score: -116.99, avg score: -220.44
# episode: 145, e: 0.05, t: 62, score: -156.93, avg score: -221.05
# episode: 146, e: 0.05, t: 81, score: -168.31, avg score: -221.58
# episode: 147, e: 0.05, t: 61, score: -128.97, avg score: -221.59
# episode: 148, e: 0.05, t: 57, score: -104.45, avg score: -219.56
# episode: 149, e: 0.05, t: 78, score: -138.72, avg score: -217.09
# episode: 150, e: 0.05, t: 67, score: -58.92, avg score: -211.63
# episode: 151, e: 0.05, t: 119, score: -178.27, avg score: -211.22
# episode: 152, e: 0.05, t: 158, score: -136.41, avg score: -211.77
# episode: 153, e: 0.05, t: 113, score: -142.81, avg score: -212.39
# episode: 154, e: 0.05, t: 92, score: -166.62, avg score: -213.55
# episode: 155, e: 0.05, t: 99, score: -242.39, avg score: -216.03
# episode: 156, e: 0.05, t: 79, score: -187.80, avg score: -217.22
# episode: 157, e: 0.05, t: 226, score: -144.29, avg score: -218.01
# episode: 158, e: 0.05, t: 122, score: -96.24, avg score: -211.76
# episode: 159, e: 0.05, t: 94, score: -105.41, avg score: -211.24
# episode: 160, e: 0.05, t: 281, score: -102.03, avg score: -211.71
# episode: 161, e: 0.05, t: 499, score: -69.84, avg score: -206.84
# episode: 162, e: 0.05, t: 295, score: -265.41, avg score: -199.96
# episode: 163, e: 0.05, t: 140, score: -93.91, avg score: -189.95
# episode: 164, e: 0.05, t: 163, score: -122.77, avg score: -182.10
# episode: 165, e: 0.05, t: 111, score: -10.55, avg score: -169.86
# episode: 166, e: 0.05, t: 499, score: -32.51, avg score: -163.12
# episode: 167, e: 0.05, t: 499, score:  4.33, avg score: -160.02
# episode: 168, e: 0.05, t: 499, score: -23.71, avg score: -157.48
# episode: 169, e: 0.05, t: 499, score:  34.55, avg score: -153.50
# episode: 170, e: 0.05, t: 499, score: -31.14, avg score: -151.50
# episode: 171, e: 0.05, t: 499, score: -4.25, avg score: -147.17
# episode: 172, e: 0.05, t: 499, score:  30.29, avg score: -143.34
# episode: 173, e: 0.05, t: 499, score: -51.09, avg score: -141.67
# episode: 174, e: 0.05, t: 499, score:  43.90, avg score: -138.07
# episode: 175, e: 0.05, t: 248, score: -145.63, avg score: -138.62
# episode: 176, e: 0.05, t: 77, score: -189.52, avg score: -140.16
# episode: 177, e: 0.05, t: 483, score: -128.49, avg score: -140.17
# episode: 178, e: 0.05, t: 499, score:  82.81, avg score: -136.09
# episode: 179, e: 0.05, t: 499, score:  7.79, avg score: -133.04
