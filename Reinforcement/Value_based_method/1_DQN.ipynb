# %%
import os
import gym
import random
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim

np.bool8 = np.bool_

# %%
#Choose device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# Hyperparameters
GAMMA = 0.99
LR = 1e-3
BATCH_SIZE = 64
BUFFER_SIZE = 100_000
TAU = 0.005              
EPSILON_START = 1.0
EPSILON_END = 0.05
EPSILON_DECAY = 0.995

# %%
class QNetwork(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(QNetwork, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, output_dim)
        )
    def forward(self, x):
        return self.net(x)

# %% [markdown]
# # Deep Q-Learning
#
# Deep Q-Learning (DQN) is an extension of traditional Q-Learning that leverages deep neural networks to approximate the action-value function $ Q(s, a; \theta) $. Instead of maintaining a tabular Q-table, a neural network with parameters $\theta$ predicts Q-values for each action given a state. Need for this change comes from the fact that Q-table will take up immeasurable memory space when the observation and action become more complicated and so become unrealistic for real problem.
#
# ## Core Components
#
# 1. **Q-Network**
#    A neural network that takes the state as input and outputs Q-values for all possible actions. It is trained to minimize the Temporal Difference (TD) error:
#    $
#    \mathcal{L}(\theta) = \mathbb{E}_{(s,a,r,s') \sim \mathcal{D}} \Bigl[ \bigl(r + \gamma \max_{a'} Q(s', a'; \theta^-) - Q(s, a; \theta)\bigr)^2 \Bigr]
#    $
#
# 2. **Target Network**
#    A second neural network with parameters $\theta^-$ that are copied periodically from the Q-Network. It provides a stable target for the Q-value updates, reducing oscillations and divergence during training.
#
# 3. **Replay Buffer (Experience Replay)**
#    A finite memory buffer $\mathcal{D}$ that stores past transitions $(s, a, r, s')$. Mini-batches sampled uniformly at random from this buffer:
#    - **Break correlation** between sequential samples.
#    - **Improve data efficiency** by reusing experiences multiple times.
#    - **Stabilize training** by smoothing over changes in data distribution.
#
# 4. **Epsilon-Greedy Policy**
#    Balances exploration and exploitation by choosing a random action with probability $\epsilon$ and the greedy action ($\arg\max_a Q(s,a)$) with probability $1 - \epsilon$. $\epsilon$ usually decays over time.
#
# ## Why Replay Buffer and Target Network?
#
# - **Replay Buffer**
#   Without experience replay, consecutive samples are highly correlated, which can lead to unstable updates and poor convergence. The buffer randomizes experience, approximating the i.i.d. assumption of stochastic gradient descent.
#
# - **Target Network**
#   Using the same network to compute both the current Q-value and the target leads to moving target problems: the network chases a constantly shifting target. More precise,when our weights update, our output Q-values will update, but so will our target Q-values since the targets are calculated using the same weights. So, our Q-values will be updated with each iteration to move closer to the target Q-values, but the target Q-values will also be moving in the same direction. This makes the optimization appear to be chasing its own tail, which introduces instability. As our Q-values move closer and closer to their targets, the targets continue to move further because we are using the same network to calculate both of these values. A target network decouples the target generation, making updates more stable.
#
# By integrating these components, DQN achieves robust and stable learning in high-dimensional state spaces, enabling successful applications in tasks like Atari game playing.

# %%
class ReplayBuffer:
    def __init__(self, capacity):
        self.buffer = []
        self.capacity = capacity
        self.position = 0

    def push(self, s, a, r, s_, done):
        data = (s, a, r, s_, done)
        if len(self.buffer) < self.capacity:
            self.buffer.append(data)
        else:
            self.buffer[self.position] = data
        self.position = (self.position + 1) % self.capacity

    def sample(self, batch_size):
        samples = random.sample(self.buffer, batch_size)
        states, actions, rewards, next_states, dones = zip(*samples)
        return (np.array(states), np.array(actions), np.array(rewards),
                np.array(next_states), np.array(dones))

    def __len__(self):
        return len(self.buffer)

# %%
class DQNAgent:
    def __init__(self, obs_dim, n_actions):
        self.obs_dim = obs_dim
        self.n_actions = n_actions
        
        self.q_net = QNetwork(obs_dim, n_actions).to(device)
        self.target_net = QNetwork(obs_dim, n_actions).to(device)
        self.target_net.load_state_dict(self.q_net.state_dict())
        self.target_net.eval()

        self.optimizer = optim.Adam(self.q_net.parameters(), lr=LR)
        self.buffer = ReplayBuffer(BUFFER_SIZE)

        self.loss_fn = nn.MSELoss()
        self.epsilon = EPSILON_START

    def act(self, state):
        if random.random() < self.epsilon:
            return random.randint(0, self.n_actions - 1)
        else:
            state_tensor = torch.FloatTensor(state).unsqueeze(0).to(device)
            with torch.no_grad():
                q_values = self.q_net(state_tensor)
            return q_values.argmax().item()

    def update(self):
        if len(self.buffer) < BATCH_SIZE:
            return

        s, a, r, s_, d = self.buffer.sample(BATCH_SIZE)

        s      = torch.FloatTensor(s).to(device)
        a      = torch.LongTensor(a).unsqueeze(1).to(device)
        r      = torch.FloatTensor(r).unsqueeze(1).to(device)
        s_     = torch.FloatTensor(s_).to(device)
        d      = torch.FloatTensor(d).unsqueeze(1).to(device)

        q_values      = self.q_net(s).gather(1, a)
        with torch.no_grad():
            next_q      = self.target_net(s_).max(1)[0].unsqueeze(1)
            target_q    = r + GAMMA * next_q * (1 - d)

        loss = self.loss_fn(q_values, target_q)

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        # Soft update
        for target_param, local_param in zip(self.target_net.parameters(), self.q_net.parameters()):
            target_param.data.copy_(TAU * local_param.data + (1.0 - TAU) * target_param.data)

    def decay_epsilon(self):
        self.epsilon = max(EPSILON_END, self.epsilon * EPSILON_DECAY)

# %%
#Trainning

env = gym.make("LunarLander-v2")
agent = DQNAgent(env.observation_space.shape[0], env.action_space.n)

episodes = 1000
scores = []
avgs = []

for ep in range(episodes):
    state, _ = env.reset(seed=ep)
    total_reward = 0
    done = False

    while not done:
        action = agent.act(state)
        next_state, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated

        agent.buffer.push(state, action, reward, next_state, done)
        agent.update()

        state = next_state
        total_reward += reward

    agent.decay_epsilon()
    scores.append(total_reward)
    avgs.append(np.mean(scores[-50:]))
    print(f"Ep {ep} | Score: {total_reward:.1f} | Avg50: {avgs[-1]:.1f} | Epsilon: {agent.epsilon:.3f}")

    if avgs[-1] >= 200:
        print("Solved!")
        break

# Plot
plt.figure(figsize=(12,5))
plt.plot(scores, label="Score per Episode")
plt.plot(avgs, label="Avg Last 50")
plt.xlabel("Episode")
plt.ylabel("Score")
plt.legend()
plt.grid()
plt.show()
plt.show()
# Out:
# Ep 0 | Score: -144.7 | Avg50: -144.7 | Epsilon: 0.995
# Ep 1 | Score: -303.3 | Avg50: -224.0 | Epsilon: 0.990
# Ep 2 | Score: -100.4 | Avg50: -182.8 | Epsilon: 0.985
# Ep 3 | Score: -319.2 | Avg50: -216.9 | Epsilon: 0.980
# Ep 4 | Score: -232.7 | Avg50: -220.0 | Epsilon: 0.975
# Ep 5 | Score: -353.9 | Avg50: -242.4 | Epsilon: 0.970
# Ep 6 | Score: -282.6 | Avg50: -248.1 | Epsilon: 0.966
# Ep 7 | Score: -215.6 | Avg50: -244.0 | Epsilon: 0.961
# Ep 8 | Score: -88.9 | Avg50: -226.8 | Epsilon: 0.956
# Ep 9 | Score: -325.0 | Avg50: -236.6 | Epsilon: 0.951
# Ep 10 | Score: -95.1 | Avg50: -223.8 | Epsilon: 0.946
# Ep 11 | Score: -102.4 | Avg50: -213.7 | Epsilon: 0.942
# Ep 12 | Score: -222.6 | Avg50: -214.3 | Epsilon: 0.937
# Ep 13 | Score: -193.9 | Avg50: -212.9 | Epsilon: 0.932
# Ep 14 | Score: -111.2 | Avg50: -206.1 | Epsilon: 0.928
# Ep 15 | Score: -95.8 | Avg50: -199.2 | Epsilon: 0.923
# Ep 16 | Score: -263.4 | Avg50: -203.0 | Epsilon: 0.918
# ...

# %%
# Run this for demo 

# env = gym.make("LunarLander-v2", render_mode="human")

# episodes = 10
# max_t = 500
# e=0
# scores = []
# avgs = []

# for episode in range(episodes):
#     observation, _ = env.reset()
    
#     score = 0
#     for t in range(max_t):
#         s = observation
#         a = agent.act(s, e)
#         observation, reward, terminated, _, _ = env.step(a)
#         score +=  reward
#         s_ = observation
#         if terminated:
#             break
