# %%
import gym
import matplotlib.pyplot as plt
import numpy as np
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import random
from IPython.display import clear_output
from collections import deque
from tqdm.notebook import tqdm
from collections import deque

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import keras.backend as K

tf.compat.v1.disable_eager_execution()

# %% [markdown]
# ## Noisy Networks
#
# ### Main Ideas:
#
# 1. **Enhancing Exploration with Parameter Noise**:
#    - Traditional exploration strategies in reinforcement learning, such as ε-greedy, involve adding randomness to action selection.
#    - **Noisy Networks (Noisy Nets)** introduce stochasticity directly into the network parameters, enabling more sophisticated and efficient exploration by incorporating parameter noise into the action-value function.
#
# 2. **Parameter-Based Exploration**:
#    - Instead of perturbing actions or rewards, Noisy Nets add noise to the network weights, allowing the agent to explore by varying its policy in a more structured manner.
#    - This approach can lead to more consistent exploration patterns and improved sample efficiency.
#
# 3. **Learnable Noise Parameters**:
#    - Noisy Nets incorporate learnable parameters for noise, allowing the network to adjust the level of stochasticity based on the learning process.
#    - This adaptability enables the agent to reduce exploration as it becomes more confident in its policy, leading to a natural annealing of exploration over time.
#
# 4. **Integration with Other Rainbow Components**:
#    - **Noisy Networks** synergize with other Rainbow DQN components, such as **Dueling Networks**, **Prioritized Experience Replay**, and **Double DQN**, to enhance overall learning efficiency and performance.
#    - When combined, these techniques provide a more comprehensive approach to tackling complex reinforcement learning tasks.
#
# ### Structure of Noisy Networks:
#
# - **Noisy Linear Layers**:
#   - Traditional linear layers in neural networks are augmented with noise, typically using factorized Gaussian noise.
#   - Each weight in the noisy linear layer is represented as:
#     $$
#     y = (b + W x) + (b_{\text{noisy}} + W_{\text{noisy}} x)
#     $$
#     where:
#     - $ b $ and $ W $ are the deterministic bias and weight parameters.
#     - $ b_{\text{noisy}} $ and $ W_{\text{noisy}} $ are the noisy bias and weight parameters.
#     - The noisy parameters are defined as:
#       $$
#       W_{\text{noisy}} = \sigma_W \odot \epsilon_{\text{out}} \epsilon_{\text{in}}^T
#       $$
#       $$
#       b_{\text{noisy}} = \sigma_b \odot \epsilon_{\text{out}}
#       $$
#       where:
#       - $ \sigma_W $ and $ \sigma_b $ are learnable standard deviation parameters.
#       - $ \epsilon_{\text{in}} $ and $ \epsilon_{\text{out}} $ are noise vectors sampled from a standard normal distribution.
#       - $ \odot $ denotes element-wise multiplication.
#       - $ \epsilon_{\text{out}} \epsilon_{\text{in}}^T $ represents the outer product, ensuring that noise is factorized across input and output dimensions.
#
# - **Factorized Gaussian Noise**:
#   - To efficiently generate noise for all weights, Noisy Nets use factorized Gaussian noise.
#   - This involves generating separate noise vectors for the input $ \epsilon_{\text{in}} $ and output $ \epsilon_{\text{out}} $ dimensions and combining them to produce the noise for each weight.
#   - The noise variables are transformed using a function $ f $ (often $ f(x) = \text{sign}(x) \sqrt{|x|} $) to ensure zero mean and unit variance, maintaining the stability of the network.
#
# - **Learnable Noise Parameters**:
#   - The parameters $ \mu_W $, $ \sigma_W $, $ \mu_b $, and $ \sigma_b $ are learned alongside the rest of the network parameters.
#   - This allows the network to adapt the level of noise based on the learning dynamics, facilitating controlled exploration.
#
# ### Why Noisy Networks?
#
# 1. **Efficient and Adaptive Exploration**:
#    - Noisy Nets provide a more efficient exploration strategy by injecting noise directly into the network parameters, allowing for richer and more consistent exploration patterns compared to simple action perturbations.
#
# 2. **Reduced Need for External Exploration Strategies**:
#    - By incorporating noise into the network itself, the reliance on external exploration mechanisms like ε-greedy is reduced, simplifying the overall architecture.
#
# 3. **Learnable Exploration Rate**:
#    - The exploration level is not fixed but learned, allowing the agent to automatically adjust the degree of exploration based on its confidence in the policy, leading to a natural annealing process.
#
# 4. **Improved Sample Efficiency**:
#    - By enabling more effective exploration, Noisy Nets can lead to faster learning and better performance with fewer training samples.
#
# ### Advantages of Noisy Networks
#
# 1. **Improved Exploration Efficiency**:
#    - Provides a structured and efficient way to explore the action space, potentially discovering better policies more quickly than random action perturbations.
#
# 2. **Adaptive Noise Levels**:
#    - The network learns to adjust the noise levels, reducing exploration as the agent becomes more certain about the optimal policy, which can enhance convergence rates.
#
# 3. **Simplified Exploration Mechanism**:
#    - Eliminates the need for manually tuning exploration parameters like ε in ε-greedy strategies, as the noise levels are learned automatically.
#
# 4. **Enhanced Performance in Complex Environments**:
#    - Particularly beneficial in environments with large or continuous action spaces, where traditional exploration methods may struggle.

# %%
class NoisyDense(tf.keras.layers.Layer):
    def __init__(self, 
                 units, 
                 activation=None,
                 trainable = True, 
                 sigma_0=0.5):
        super(NoisyDense, self).__init__()
        self.units = units
        self.activation = tf.keras.activations.get(activation)
        self.trainable = trainable
        self.sigma_0 = sigma_0

    def build(self, input_shape):
        input_dim = input_shape[-1]
        self.w_mu = self.add_weight(
            name="w_mu",
            shape=(input_dim, self.units),
            initializer=tf.keras.initializers.RandomUniform(
                minval=-1. / np.sqrt(input_dim),
                maxval=1. / np.sqrt(input_dim)
            ),
            trainable=self.trainable
        )

        self.w_sigma = self.add_weight(
            name="w_sigma",
            shape=(input_dim, self.units),
            initializer=tf.keras.initializers.Constant(self.sigma_0 / np.sqrt(input_dim)),
            trainable=self.trainable
        )

        self.b_mu = self.add_weight(
            name="b_mu",
            shape=(self.units,),
            initializer=tf.keras.initializers.RandomUniform(
                minval=-1. / np.sqrt(input_dim),
                maxval=1. / np.sqrt(input_dim)
            ),
            trainable=self.trainable
        )

        self.b_sigma = self.add_weight(
            name="b_sigma",
            shape=(self.units,),
            initializer=tf.keras.initializers.Constant(self.sigma_0 / np.sqrt(input_dim)),
            trainable=True
        )

    def call(self, inputs):
        # Add noise
        epsilon_in = self.f(tf.random.normal(shape=(self.w_mu.shape[0], 1)))
        epsilon_out = self.f(tf.random.normal(shape=(1, self.w_mu.shape[1])))

        w_epsilon = tf.matmul(epsilon_in, epsilon_out)
        b_epsilon = epsilon_out

        w = self.w_mu + self.w_sigma * w_epsilon
        b = self.b_mu + self.b_sigma * b_epsilon
        
        output = tf.matmul(inputs, w) + b
        if self.activation is not None:
            output = self.activation(output)
        return output

    @staticmethod
    def f(x):
        return tf.sign(x) * tf.sqrt(tf.abs(x) + 1e-10)

# %%
class Noisy_Agent():
    def __init__(
            self,
            observation_space,
            action_space,
            gamma = 0.99,
            lr = 0.001,
            maxlen = 50000,):
        
        self.observation_space = observation_space
        self.action_space = action_space
        self.gamma = gamma
        self.lr = lr
        self.buffer = deque(maxlen=maxlen)

        self.model = self.build_model(name = "model")
        self.target_model = self.build_model(name = "target")
        self.update_target()

    def remember(self,state, action, reward, next_state, done):
        self.buffer.append([state, action, reward, next_state, done])

    def get_batch(self, batch_size):
        if len(self.buffer) < batch_size:
            return None
        
        batch = random.sample(self.buffer, k=batch_size)
        
        S = np.array([val[0] for val in batch])
        A = np.array([val[1] for val in batch])
        R = np.array([val[2] for val in batch])
        S_ = np.array([val[3] for val in batch])
        T = np.array([val[4] for val in batch])

        return S, A, R, S_, T

    
    def build_model(self, name):
        model = keras.Sequential(name=name)
        model.add(keras.layers.InputLayer(input_shape=self.observation_space))
        model.add(NoisyDense(128, activation='relu'))
        model.add(NoisyDense(128, activation='relu'))
        model.add(NoisyDense(128, activation='relu'))
        model.add(NoisyDense(self.action_space, activation=None))
        model.compile(
            optimizer=keras.optimizers.Adam(learning_rate=self.lr),
            loss='mse'
        )
        return model

    def update_target(self):
        self.target_model.set_weights(self.model.get_weights())

    def predict(self, observation, target = False):
        if target:
            return self.target_model.predict(np.array([observation]), verbose = False)[0]
        return self.model.predict(np.array([observation]), verbose= False)[0]
    
    def predict_action(self, observation, epsilon=0.05):
        if np.random.random() < epsilon:
            return np.random.randint(self.action_space)
        return np.argmax(self.model.predict(np.array([observation]), verbose=False)[0])
    
    def train(self, batch_size):
        if len(self.buffer) < batch_size:
            return
        
        S, A, R, S_, T = self.get_batch(batch_size)
        
        Q_values = self.model.predict(S, verbose=False)
        
        Q_next = self.target_model.predict(S_, verbose=False)
        
        max_Q_next = np.max(Q_next, axis = 1)

        targets = Q_values.copy()
        targets[np.arange(batch_size), A] = R + self.gamma * max_Q_next * (1 - T)

        self.model.fit(S, targets, verbose=False)

# %%
env = gym.make("LunarLander-v2")
agent = Noisy_Agent(env.observation_space.shape, env.action_space.n)

episodes = 2000
max_t = 500
e=0.05
scores = []
avgs = []
time = 0
frequency = 400

for episode in range(episodes):
    observation, _ = env.reset()
    
    score = 0
    for t in range(max_t):
        time += 1
        s = observation
        a = agent.predict_action(s, e)
        observation, reward, terminated, _, _ = env.step(a)
        score +=  reward
        s_ = observation
        agent.remember(s, a, reward, s_, terminated)
        agent.train(batch_size=32)
        if time % frequency == 0:
            agent.update_target()
        if terminated:
            break
    scores.append(score)
    avgs.append(np.sum(scores[-50:])/len(scores[-50:]))
    print(f"episode: {episode}, e: {e}, t: {t}, score: {score : .2f}, avg score: {avgs[-1]: .2f}")
    if avgs[-1] >= 200:
        break
# Out:
# c:\Users\admin\anaconda3\envs\test\lib\site-packages\keras\engine\training_v1.py:2356: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# c:\Users\admin\anaconda3\envs\test\lib\site-packages\gym\utils\passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# episode: 0, e: 0.05, t: 83, score: -288.28, avg score: -288.28
# episode: 1, e: 0.05, t: 55, score: -321.83, avg score: -305.05
# episode: 2, e: 0.05, t: 90, score: -339.97, avg score: -316.69
# episode: 3, e: 0.05, t: 75, score: -249.51, avg score: -299.90
# episode: 4, e: 0.05, t: 78, score: -621.52, avg score: -364.22
# episode: 5, e: 0.05, t: 50, score: -323.85, avg score: -357.49
# episode: 6, e: 0.05, t: 65, score: -517.15, avg score: -380.30
# episode: 7, e: 0.05, t: 86, score: -392.55, avg score: -381.83
# episode: 8, e: 0.05, t: 134, score: -517.89, avg score: -396.95
# episode: 9, e: 0.05, t: 97, score: -581.84, avg score: -415.44
# episode: 10, e: 0.05, t: 68, score: -636.42, avg score: -435.53
# episode: 11, e: 0.05, t: 55, score: -316.51, avg score: -425.61
# episode: 12, e: 0.05, t: 96, score: -607.85, avg score: -439.63
# episode: 13, e: 0.05, t: 92, score: -95.09, avg score: -415.02
# episode: 14, e: 0.05, t: 62, score: -224.90, avg score: -402.35
# episode: 15, e: 0.05, t: 131, score: -575.56, avg score: -413.17
# episode: 16, e: 0.05, t: 57, score: -357.60, avg score: -409.90
# episode: 17, e: 0.05, t: 56, score: -358.50, avg score: -407.05
# episode: 18, e: 0.05, t: 93, score: -48.78, avg score: -388.19
# episode: 19, e: 0.05, t: 81, score: -17.27, avg score: -369.64
# episode: 20, e: 0.05, t: 111, score: -170.97, avg score: -360.18
# episode: 21, e: 0.05, t: 89, score: -200.85, avg score: -352.94
# episode: 22, e: 0.05, t: 105, score: -453.29, avg score: -357.30
# episode: 23, e: 0.05, t: 77, score: -246.57, avg score: -352.69
# episode: 24, e: 0.05, t: 106, score: -125.07, avg score: -343.59
# episode: 25, e: 0.05, t: 61, score: -143.05, avg score: -335.87
# episode: 26, e: 0.05, t: 111, score: -78.01, avg score: -326.32
# episode: 27, e: 0.05, t: 125, score: -48.32, avg score: -316.39
# episode: 28, e: 0.05, t: 58, score: -108.65, avg score: -309.23
# episode: 29, e: 0.05, t: 67, score: -218.46, avg score: -306.20
# episode: 30, e: 0.05, t: 50, score: -144.86, avg score: -301.00
# episode: 31, e: 0.05, t: 64, score: -212.99, avg score: -298.25
# episode: 32, e: 0.05, t: 212, score: -446.06, avg score: -302.73
# episode: 33, e: 0.05, t: 104, score: -82.73, avg score: -296.26
# episode: 34, e: 0.05, t: 85, score: -142.97, avg score: -291.88
# episode: 35, e: 0.05, t: 64, score: -127.80, avg score: -287.32
# episode: 36, e: 0.05, t: 59, score: -133.16, avg score: -283.15
# episode: 37, e: 0.05, t: 85, score: -122.14, avg score: -278.92
# episode: 38, e: 0.05, t: 88, score: -123.17, avg score: -274.92
# episode: 39, e: 0.05, t: 99, score: -113.46, avg score: -270.89
# episode: 40, e: 0.05, t: 499, score: -51.43, avg score: -265.53
# episode: 41, e: 0.05, t: 499, score: -83.60, avg score: -261.20
# episode: 42, e: 0.05, t: 499, score: -68.36, avg score: -256.72
# episode: 43, e: 0.05, t: 499, score: -3.19, avg score: -250.96
# episode: 44, e: 0.05, t: 499, score:  11.07, avg score: -245.13
# episode: 45, e: 0.05, t: 499, score:  27.32, avg score: -239.21
# episode: 46, e: 0.05, t: 499, score: -39.06, avg score: -234.95
# episode: 47, e: 0.05, t: 499, score:  41.16, avg score: -229.20
# episode: 48, e: 0.05, t: 499, score: -15.07, avg score: -224.83
# episode: 49, e: 0.05, t: 499, score:  25.25, avg score: -219.83
# episode: 50, e: 0.05, t: 499, score:  30.83, avg score: -213.45
# episode: 51, e: 0.05, t: 499, score:  38.07, avg score: -206.25
# episode: 52, e: 0.05, t: 499, score:  21.60, avg score: -199.02
# episode: 53, e: 0.05, t: 499, score:  31.37, avg score: -193.40
# episode: 54, e: 0.05, t: 499, score:  3.86, avg score: -180.89
# episode: 55, e: 0.05, t: 499, score:  8.31, avg score: -174.25
# episode: 56, e: 0.05, t: 499, score: -65.82, avg score: -165.22
# episode: 57, e: 0.05, t: 499, score:  21.96, avg score: -156.93
# episode: 58, e: 0.05, t: 499, score:  1.82, avg score: -146.54
# episode: 59, e: 0.05, t: 499, score: -37.95, avg score: -135.66
# episode: 60, e: 0.05, t: 499, score: -40.25, avg score: -123.74
# episode: 61, e: 0.05, t: 159, score: -99.19, avg score: -119.39
# episode: 62, e: 0.05, t: 499, score: -135.71, avg score: -109.95
# episode: 63, e: 0.05, t: 499, score: -0.79, avg score: -108.06
# episode: 64, e: 0.05, t: 499, score: -12.75, avg score: -103.82
# episode: 65, e: 0.05, t: 499, score: -60.29, avg score: -93.51
# episode: 66, e: 0.05, t: 499, score:  2.85, avg score: -86.30
# episode: 67, e: 0.05, t: 499, score:  25.16, avg score: -78.63
# episode: 68, e: 0.05, t: 499, score: -41.28, avg score: -78.48
# episode: 69, e: 0.05, t: 499, score:  26.64, avg score: -77.60
# episode: 70, e: 0.05, t: 499, score: -18.02, avg score: -74.54
# episode: 71, e: 0.05, t: 499, score:  57.19, avg score: -69.38
# episode: 72, e: 0.05, t: 499, score: -3.78, avg score: -60.39
# episode: 73, e: 0.05, t: 499, score:  19.33, avg score: -55.07
# episode: 74, e: 0.05, t: 161, score:  63.32, avg score: -51.30
# episode: 75, e: 0.05, t: 499, score: -21.93, avg score: -48.88
# episode: 76, e: 0.05, t: 499, score:  14.53, avg score: -47.03
# episode: 77, e: 0.05, t: 499, score: -50.76, avg score: -47.08
# episode: 78, e: 0.05, t: 499, score:  52.43, avg score: -43.86
# episode: 79, e: 0.05, t: 499, score:  54.05, avg score: -38.41
# episode: 80, e: 0.05, t: 499, score:  28.76, avg score: -34.94
# episode: 81, e: 0.05, t: 499, score:  32.56, avg score: -30.03
# episode: 82, e: 0.05, t: 499, score:  27.35, avg score: -20.56
# episode: 83, e: 0.05, t: 499, score:  99.97, avg score: -16.90
# episode: 84, e: 0.05, t: 499, score:  21.47, avg score: -13.61
# episode: 85, e: 0.05, t: 499, score:  52.19, avg score: -10.01
# episode: 86, e: 0.05, t: 499, score:  9.71, avg score: -7.16
# episode: 87, e: 0.05, t: 499, score:  67.70, avg score: -3.36
# episode: 88, e: 0.05, t: 499, score:  16.92, avg score: -0.56
# episode: 89, e: 0.05, t: 499, score:  36.44, avg score:  2.44
# episode: 90, e: 0.05, t: 499, score:  7.25, avg score:  3.61
# episode: 91, e: 0.05, t: 459, score: -136.36, avg score:  2.56
# episode: 92, e: 0.05, t: 272, score: -233.17, avg score: -0.74
# episode: 93, e: 0.05, t: 164, score: -144.03, avg score: -3.56
# episode: 94, e: 0.05, t: 499, score:  63.34, avg score: -2.51
# episode: 95, e: 0.05, t: 499, score:  21.12, avg score: -2.63
# episode: 96, e: 0.05, t: 499, score:  35.50, avg score: -1.14
# episode: 97, e: 0.05, t: 499, score:  51.46, avg score: -0.94
# episode: 98, e: 0.05, t: 237, score: -69.14, avg score: -2.02
# episode: 99, e: 0.05, t: 388, score: -199.59, avg score: -6.51
# episode: 100, e: 0.05, t: 499, score:  10.68, avg score: -6.92
# episode: 101, e: 0.05, t: 131, score: -141.10, avg score: -10.50
# episode: 102, e: 0.05, t: 499, score:  21.85, avg score: -10.50
# episode: 103, e: 0.05, t: 499, score:  21.13, avg score: -10.70
# episode: 104, e: 0.05, t: 371, score: -159.36, avg score: -13.97
# episode: 105, e: 0.05, t: 499, score:  27.24, avg score: -13.59
# episode: 106, e: 0.05, t: 174, score: -97.49, avg score: -14.22
# episode: 107, e: 0.05, t: 499, score: -12.81, avg score: -14.92
# episode: 108, e: 0.05, t: 499, score: -73.39, avg score: -16.42
# episode: 109, e: 0.05, t: 499, score:  36.13, avg score: -14.94
# episode: 110, e: 0.05, t: 499, score:  92.48, avg score: -12.28
# episode: 111, e: 0.05, t: 499, score:  55.78, avg score: -9.18
# episode: 112, e: 0.05, t: 499, score:  18.97, avg score: -6.09
# episode: 113, e: 0.05, t: 499, score:  46.91, avg score: -5.14
# episode: 114, e: 0.05, t: 499, score:  27.14, avg score: -4.34
# episode: 115, e: 0.05, t: 383, score: -191.60, avg score: -6.97
# episode: 116, e: 0.05, t: 499, score:  49.29, avg score: -6.04
# episode: 117, e: 0.05, t: 499, score:  63.07, avg score: -5.28
# episode: 118, e: 0.05, t: 499, score:  40.43, avg score: -3.64
# episode: 119, e: 0.05, t: 499, score:  18.68, avg score: -3.80
# episode: 120, e: 0.05, t: 499, score:  65.04, avg score: -2.14
# episode: 121, e: 0.05, t: 499, score:  47.49, avg score: -2.34
# episode: 122, e: 0.05, t: 499, score: -7.94, avg score: -2.42
# episode: 123, e: 0.05, t: 499, score:  76.10, avg score: -1.28
# episode: 124, e: 0.05, t: 499, score:  36.21, avg score: -1.83
# episode: 125, e: 0.05, t: 443, score: -149.57, avg score: -4.38
# episode: 126, e: 0.05, t: 499, score: -31.92, avg score: -5.31
# episode: 127, e: 0.05, t: 499, score: -105.80, avg score: -6.41
# episode: 128, e: 0.05, t: 327, score: -126.53, avg score: -9.99
# episode: 129, e: 0.05, t: 499, score: -13.35, avg score: -11.34
# episode: 130, e: 0.05, t: 499, score:  35.30, avg score: -11.21
# episode: 131, e: 0.05, t: 499, score:  36.99, avg score: -11.12
# episode: 132, e: 0.05, t: 499, score: -27.36, avg score: -12.21
# episode: 133, e: 0.05, t: 499, score:  31.75, avg score: -13.58
# episode: 134, e: 0.05, t: 499, score:  23.17, avg score: -13.54
# episode: 135, e: 0.05, t: 291, score: -208.40, avg score: -18.75
# episode: 136, e: 0.05, t: 499, score:  41.23, avg score: -18.12
# episode: 137, e: 0.05, t: 499, score:  41.94, avg score: -18.64
# episode: 138, e: 0.05, t: 499, score:  24.96, avg score: -18.48
# episode: 139, e: 0.05, t: 499, score: -3.72, avg score: -19.28
# episode: 140, e: 0.05, t: 499, score:  9.87, avg score: -19.23
# episode: 141, e: 0.05, t: 499, score:  36.36, avg score: -15.77
# episode: 142, e: 0.05, t: 499, score:  50.66, avg score: -10.10
# episode: 143, e: 0.05, t: 499, score:  35.93, avg score: -6.50
# episode: 144, e: 0.05, t: 499, score:  57.00, avg score: -6.62
# episode: 145, e: 0.05, t: 499, score:  45.99, avg score: -6.13
# episode: 146, e: 0.05, t: 499, score:  32.74, avg score: -6.18
# episode: 147, e: 0.05, t: 499, score:  56.13, avg score: -6.09
# episode: 148, e: 0.05, t: 499, score:  46.11, avg score: -3.78
# episode: 149, e: 0.05, t: 499, score: -0.85, avg score:  0.19
# episode: 150, e: 0.05, t: 499, score:  80.24, avg score:  1.58
# episode: 151, e: 0.05, t: 499, score:  20.84, avg score:  4.82
# episode: 152, e: 0.05, t: 499, score:  67.67, avg score:  5.74
# episode: 153, e: 0.05, t: 499, score:  36.34, avg score:  6.04
# episode: 154, e: 0.05, t: 499, score:  90.21, avg score:  11.03
# episode: 155, e: 0.05, t: 499, score: -25.09, avg score:  9.99
# episode: 156, e: 0.05, t: 499, score:  13.83, avg score:  12.21
# episode: 157, e: 0.05, t: 499, score: -43.62, avg score:  11.60
# episode: 158, e: 0.05, t: 499, score: -19.92, avg score:  12.67
# episode: 159, e: 0.05, t: 499, score: -15.70, avg score:  11.63
# episode: 160, e: 0.05, t: 499, score:  11.50, avg score:  10.01
# episode: 161, e: 0.05, t: 499, score: -2.48, avg score:  8.85
# episode: 162, e: 0.05, t: 499, score:  60.83, avg score:  9.68
# episode: 163, e: 0.05, t: 499, score: -38.96, avg score:  7.97
# episode: 164, e: 0.05, t: 499, score:  30.20, avg score:  8.03
# episode: 165, e: 0.05, t: 499, score: -5.71, avg score:  11.74
# episode: 166, e: 0.05, t: 499, score: -23.50, avg score:  10.29
# episode: 167, e: 0.05, t: 499, score: -8.83, avg score:  8.85
# episode: 168, e: 0.05, t: 499, score: -35.68, avg score:  7.33
# episode: 169, e: 0.05, t: 499, score:  49.41, avg score:  7.94
# episode: 170, e: 0.05, t: 499, score: -6.08, avg score:  6.52
# episode: 171, e: 0.05, t: 499, score:  5.23, avg score:  5.68
# episode: 172, e: 0.05, t: 499, score:  91.19, avg score:  7.66
# episode: 173, e: 0.05, t: 499, score:  8.74, avg score:  6.31
# episode: 174, e: 0.05, t: 499, score:  38.42, avg score:  6.35
# episode: 175, e: 0.05, t: 499, score:  61.14, avg score:  10.57
# episode: 176, e: 0.05, t: 499, score:  0.85, avg score:  11.22
# episode: 177, e: 0.05, t: 499, score:  64.17, avg score:  14.62
# episode: 178, e: 0.05, t: 499, score:  37.08, avg score:  17.90
# episode: 179, e: 0.05, t: 499, score:  51.93, avg score:  19.20
# episode: 180, e: 0.05, t: 499, score:  51.82, avg score:  19.53
# episode: 181, e: 0.05, t: 499, score:  86.75, avg score:  20.53
# episode: 182, e: 0.05, t: 499, score:  49.05, avg score:  22.06
# episode: 183, e: 0.05, t: 499, score:  90.86, avg score:  23.24
# episode: 184, e: 0.05, t: 499, score:  77.28, avg score:  24.32
# episode: 185, e: 0.05, t: 499, score:  0.38, avg score:  28.50
# episode: 186, e: 0.05, t: 499, score:  66.05, avg score:  28.99
# episode: 187, e: 0.05, t: 499, score:  5.80, avg score:  28.27
# episode: 188, e: 0.05, t: 499, score:  71.55, avg score:  29.20
# episode: 189, e: 0.05, t: 499, score:  13.76, avg score:  29.55
# episode: 190, e: 0.05, t: 499, score:  18.63, avg score:  29.73
# episode: 191, e: 0.05, t: 499, score:  72.28, avg score:  30.44
# episode: 192, e: 0.05, t: 499, score:  93.62, avg score:  31.30
# episode: 193, e: 0.05, t: 499, score:  2.23, avg score:  30.63
# episode: 194, e: 0.05, t: 499, score:  139.90, avg score:  32.29
# episode: 195, e: 0.05, t: 499, score:  32.09, avg score:  32.01
# episode: 196, e: 0.05, t: 499, score:  43.90, avg score:  32.23
# episode: 197, e: 0.05, t: 499, score:  19.81, avg score:  31.51
# episode: 198, e: 0.05, t: 499, score: -22.20, avg score:  30.14
# episode: 199, e: 0.05, t: 499, score: -1.25, avg score:  30.13
# episode: 200, e: 0.05, t: 499, score: -11.02, avg score:  28.31
# episode: 201, e: 0.05, t: 499, score: -28.01, avg score:  27.33
# episode: 202, e: 0.05, t: 499, score:  36.83, avg score:  26.71
# episode: 203, e: 0.05, t: 499, score: -17.01, avg score:  25.65
# episode: 204, e: 0.05, t: 454, score: -79.26, avg score:  22.26
# episode: 205, e: 0.05, t: 499, score:  96.32, avg score:  24.68
# episode: 206, e: 0.05, t: 499, score:  50.23, avg score:  25.41
# episode: 207, e: 0.05, t: 499, score:  28.88, avg score:  26.86
# episode: 208, e: 0.05, t: 499, score: -12.50, avg score:  27.01
# episode: 209, e: 0.05, t: 142, score: -24.65, avg score:  26.83
# episode: 210, e: 0.05, t: 499, score:  13.47, avg score:  26.87
# episode: 211, e: 0.05, t: 499, score:  111.49, avg score:  29.15
# episode: 212, e: 0.05, t: 499, score:  45.94, avg score:  28.85
# episode: 213, e: 0.05, t: 499, score:  16.91, avg score:  29.97
# episode: 214, e: 0.05, t: 499, score: -14.17, avg score:  29.08
# episode: 215, e: 0.05, t: 499, score:  36.50, avg score:  29.93
# episode: 216, e: 0.05, t: 499, score:  8.50, avg score:  30.57
# episode: 217, e: 0.05, t: 499, score:  70.27, avg score:  32.15
# episode: 218, e: 0.05, t: 499, score:  47.07, avg score:  33.80
# episode: 219, e: 0.05, t: 499, score:  41.07, avg score:  33.64
# episode: 220, e: 0.05, t: 450, score:  251.82, avg score:  38.79
# episode: 221, e: 0.05, t: 499, score:  80.62, avg score:  40.30
# episode: 222, e: 0.05, t: 499, score:  12.66, avg score:  38.73
# episode: 223, e: 0.05, t: 499, score:  75.79, avg score:  40.07
# episode: 224, e: 0.05, t: 499, score:  101.28, avg score:  41.33
# episode: 225, e: 0.05, t: 499, score:  82.81, avg score:  41.76
# episode: 226, e: 0.05, t: 499, score:  44.71, avg score:  42.64
# episode: 227, e: 0.05, t: 137, score: -636.56, avg score:  28.63
# episode: 228, e: 0.05, t: 499, score:  20.65, avg score:  28.30
# episode: 229, e: 0.05, t: 499, score: -20.57, avg score:  26.85
# episode: 230, e: 0.05, t: 499, score:  44.39, avg score:  26.70
# episode: 231, e: 0.05, t: 499, score:  83.77, avg score:  26.64
# episode: 232, e: 0.05, t: 499, score:  15.40, avg score:  25.97
# episode: 233, e: 0.05, t: 499, score:  58.67, avg score:  25.32
# episode: 234, e: 0.05, t: 499, score:  15.09, avg score:  24.08
# episode: 235, e: 0.05, t: 499, score: -18.87, avg score:  23.69
# episode: 236, e: 0.05, t: 499, score:  74.72, avg score:  23.87
# episode: 237, e: 0.05, t: 499, score:  52.88, avg score:  24.81
# episode: 238, e: 0.05, t: 499, score:  9.54, avg score:  23.57
# episode: 239, e: 0.05, t: 499, score: -17.92, avg score:  22.93
# episode: 240, e: 0.05, t: 499, score:  27.83, avg score:  23.12
# episode: 241, e: 0.05, t: 499, score:  34.49, avg score:  22.36
# episode: 242, e: 0.05, t: 499, score: -7.72, avg score:  20.34
# episode: 243, e: 0.05, t: 499, score:  46.75, avg score:  21.23
# episode: 244, e: 0.05, t: 499, score:  50.44, avg score:  19.44
# episode: 245, e: 0.05, t: 499, score:  63.49, avg score:  20.07
# episode: 246, e: 0.05, t: 499, score:  30.19, avg score:  19.79
# episode: 247, e: 0.05, t: 422, score: -118.12, avg score:  17.03
# episode: 248, e: 0.05, t: 499, score:  50.43, avg score:  18.49
# episode: 249, e: 0.05, t: 499, score:  38.45, avg score:  19.28
# episode: 250, e: 0.05, t: 499, score:  85.71, avg score:  21.21
# episode: 251, e: 0.05, t: 499, score:  38.63, avg score:  22.55
# episode: 252, e: 0.05, t: 499, score:  7.37, avg score:  21.96
# episode: 253, e: 0.05, t: 499, score:  24.45, avg score:  22.79
# episode: 254, e: 0.05, t: 499, score:  98.11, avg score:  26.33
# episode: 255, e: 0.05, t: 499, score:  41.65, avg score:  25.24
# episode: 256, e: 0.05, t: 499, score:  11.65, avg score:  24.47
# episode: 257, e: 0.05, t: 499, score:  32.03, avg score:  24.53
# episode: 258, e: 0.05, t: 499, score:  48.20, avg score:  25.75
# episode: 259, e: 0.05, t: 499, score:  59.69, avg score:  27.43
# episode: 260, e: 0.05, t: 241, score:  5.54, avg score:  27.27
# episode: 261, e: 0.05, t: 365, score:  229.75, avg score:  29.64
# episode: 262, e: 0.05, t: 499, score:  40.06, avg score:  29.52
# episode: 263, e: 0.05, t: 499, score:  69.21, avg score:  30.57
# episode: 264, e: 0.05, t: 499, score:  61.18, avg score:  32.07
# episode: 265, e: 0.05, t: 280, score: -41.70, avg score:  30.51
# episode: 266, e: 0.05, t: 499, score:  49.63, avg score:  31.33
# episode: 267, e: 0.05, t: 499, score:  14.28, avg score:  30.21
# episode: 268, e: 0.05, t: 499, score:  123.48, avg score:  31.74
# episode: 269, e: 0.05, t: 139, score: -61.79, avg score:  29.68
# episode: 270, e: 0.05, t: 499, score:  89.28, avg score:  26.43
# episode: 271, e: 0.05, t: 499, score:  32.29, avg score:  25.47
# episode: 272, e: 0.05, t: 499, score:  89.02, avg score:  26.99
# episode: 273, e: 0.05, t: 499, score:  25.39, avg score:  25.99
# episode: 274, e: 0.05, t: 353, score: -78.42, avg score:  22.39
# episode: 275, e: 0.05, t: 499, score:  62.43, avg score:  21.99
# episode: 276, e: 0.05, t: 216, score: -17.87, avg score:  20.73
# episode: 277, e: 0.05, t: 180, score:  0.46, avg score:  33.47
# episode: 278, e: 0.05, t: 499, score:  2.65, avg score:  33.11
# episode: 279, e: 0.05, t: 229, score: -67.27, avg score:  32.18
# episode: 280, e: 0.05, t: 499, score:  9.53, avg score:  31.48
# episode: 281, e: 0.05, t: 241, score:  259.31, avg score:  34.99
# episode: 282, e: 0.05, t: 277, score:  237.78, avg score:  39.44
# episode: 283, e: 0.05, t: 109, score: -326.53, avg score:  31.74
# episode: 284, e: 0.05, t: 499, score:  23.46, avg score:  31.90
# episode: 285, e: 0.05, t: 499, score:  103.72, avg score:  34.36
# episode: 286, e: 0.05, t: 106, score: -0.15, avg score:  32.86
# episode: 287, e: 0.05, t: 117, score: -36.57, avg score:  31.07
# episode: 288, e: 0.05, t: 144, score: -184.47, avg score:  27.19
# episode: 289, e: 0.05, t: 165, score: -263.39, avg score:  22.28
# episode: 290, e: 0.05, t: 499, score:  32.10, avg score:  22.37
# episode: 291, e: 0.05, t: 499, score:  23.69, avg score:  22.15
# episode: 292, e: 0.05, t: 499, score: -26.44, avg score:  21.78
# episode: 293, e: 0.05, t: 321, score:  242.37, avg score:  25.69
# episode: 294, e: 0.05, t: 329, score:  252.73, avg score:  29.73
# episode: 295, e: 0.05, t: 83, score:  2.31, avg score:  28.51
# episode: 296, e: 0.05, t: 499, score:  1.28, avg score:  27.93
# episode: 297, e: 0.05, t: 479, score:  171.41, avg score:  33.72
# episode: 298, e: 0.05, t: 396, score: -106.85, avg score:  30.58
# episode: 299, e: 0.05, t: 496, score: -147.00, avg score:  26.87
# episode: 300, e: 0.05, t: 499, score:  33.54, avg score:  25.82
# episode: 301, e: 0.05, t: 337, score: -186.04, avg score:  21.33
# episode: 302, e: 0.05, t: 352, score: -92.84, avg score:  19.33
# episode: 303, e: 0.05, t: 499, score:  72.74, avg score:  20.29
# episode: 304, e: 0.05, t: 499, score:  45.30, avg score:  19.24
# episode: 305, e: 0.05, t: 499, score:  160.64, avg score:  21.62
# episode: 306, e: 0.05, t: 483, score:  245.61, avg score:  26.30
# episode: 307, e: 0.05, t: 499, score:  73.16, avg score:  27.12
# episode: 308, e: 0.05, t: 499, score:  35.41, avg score:  26.86
# episode: 309, e: 0.05, t: 499, score:  31.78, avg score:  26.30
# episode: 310, e: 0.05, t: 270, score:  235.03, avg score:  30.89
# episode: 311, e: 0.05, t: 437, score:  222.87, avg score:  30.76
# episode: 312, e: 0.05, t: 499, score:  4.79, avg score:  30.05
# episode: 313, e: 0.05, t: 499, score:  77.11, avg score:  30.21
# episode: 314, e: 0.05, t: 499, score: -1.53, avg score:  28.95
# episode: 315, e: 0.05, t: 287, score:  256.34, avg score:  34.92
# episode: 316, e: 0.05, t: 89, score: -44.81, avg score:  33.03
# episode: 317, e: 0.05, t: 499, score:  81.11, avg score:  34.36
# episode: 318, e: 0.05, t: 252, score:  33.08, avg score:  32.56
# episode: 319, e: 0.05, t: 59, score: -49.47, avg score:  32.80
# episode: 320, e: 0.05, t: 499, score:  34.89, avg score:  31.71
# episode: 321, e: 0.05, t: 499, score:  36.24, avg score:  31.79
# episode: 322, e: 0.05, t: 499, score:  69.25, avg score:  31.40
# episode: 323, e: 0.05, t: 499, score:  58.97, avg score:  32.07
# episode: 324, e: 0.05, t: 499, score:  44.39, avg score:  34.53
# episode: 325, e: 0.05, t: 499, score:  33.72, avg score:  33.95
# episode: 326, e: 0.05, t: 499, score:  21.34, avg score:  34.74
# episode: 327, e: 0.05, t: 329, score:  269.43, avg score:  40.11
# episode: 328, e: 0.05, t: 473, score:  239.80, avg score:  44.86
# episode: 329, e: 0.05, t: 499, score:  89.30, avg score:  47.99
# episode: 330, e: 0.05, t: 447, score:  202.42, avg score:  51.85
# episode: 331, e: 0.05, t: 155, score:  23.06, avg score:  47.12
# episode: 332, e: 0.05, t: 499, score:  99.46, avg score:  44.36
# episode: 333, e: 0.05, t: 499, score:  75.80, avg score:  52.40
# episode: 334, e: 0.05, t: 403, score:  249.55, avg score:  56.92
# episode: 335, e: 0.05, t: 340, score:  248.55, avg score:  59.82
# episode: 336, e: 0.05, t: 499, score:  112.03, avg score:  62.06
# episode: 337, e: 0.05, t: 349, score:  234.17, avg score:  67.48
# episode: 338, e: 0.05, t: 499, score:  115.29, avg score:  73.47
# episode: 339, e: 0.05, t: 275, score:  250.85, avg score:  83.76
# episode: 340, e: 0.05, t: 499, score:  61.99, avg score:  84.36
# episode: 341, e: 0.05, t: 499, score:  31.94, avg score:  84.52
# episode: 342, e: 0.05, t: 234, score:  302.09, avg score:  91.09
# episode: 343, e: 0.05, t: 322, score:  268.48, avg score:  91.61
# episode: 344, e: 0.05, t: 302, score:  274.92, avg score:  92.06
# episode: 345, e: 0.05, t: 308, score:  275.28, avg score:  97.52
# episode: 346, e: 0.05, t: 499, score: -2.01, avg score:  97.45
# episode: 347, e: 0.05, t: 212, score:  264.98, avg score:  99.32
# episode: 348, e: 0.05, t: 499, score:  171.88, avg score:  104.90
# episode: 349, e: 0.05, t: 173, score:  9.45, avg score:  108.03
# episode: 350, e: 0.05, t: 499, score:  75.53, avg score:  108.87
# episode: 351, e: 0.05, t: 499, score:  26.89, avg score:  113.13
# episode: 352, e: 0.05, t: 289, score:  257.35, avg score:  120.13
# episode: 353, e: 0.05, t: 499, score: -22.20, avg score:  118.23
# episode: 354, e: 0.05, t: 383, score:  285.72, avg score:  123.04
# episode: 355, e: 0.05, t: 499, score:  53.91, avg score:  120.90
# episode: 356, e: 0.05, t: 499, score:  74.33, avg score:  117.48
# episode: 357, e: 0.05, t: 296, score:  231.13, avg score:  120.64
# episode: 358, e: 0.05, t: 238, score:  298.70, avg score:  125.90
# episode: 359, e: 0.05, t: 499, score:  98.00, avg score:  127.23
# episode: 360, e: 0.05, t: 431, score:  194.67, avg score:  126.42
# episode: 361, e: 0.05, t: 499, score:  81.60, avg score:  123.60
# episode: 362, e: 0.05, t: 499, score:  71.79, avg score:  124.94
# episode: 363, e: 0.05, t: 476, score:  214.02, avg score:  127.67
# episode: 364, e: 0.05, t: 136, score:  3.90, avg score:  127.78
# episode: 365, e: 0.05, t: 499, score:  19.44, avg score:  123.04
# episode: 366, e: 0.05, t: 499, score:  52.31, avg score:  124.99
# episode: 367, e: 0.05, t: 270, score:  285.96, avg score:  129.08
# episode: 368, e: 0.05, t: 335, score:  264.39, avg score:  133.71
# episode: 369, e: 0.05, t: 180, score:  21.54, avg score:  135.13
# episode: 370, e: 0.05, t: 246, score: -54.09, avg score:  133.35
# episode: 371, e: 0.05, t: 315, score: -33.47, avg score:  131.96
# episode: 372, e: 0.05, t: 125, score: -23.20, avg score:  130.11
# episode: 373, e: 0.05, t: 257, score:  276.67, avg score:  134.46
# episode: 374, e: 0.05, t: 160, score:  39.32, avg score:  134.36
# episode: 375, e: 0.05, t: 300, score:  203.78, avg score:  137.76
# episode: 376, e: 0.05, t: 123, score: -47.33, avg score:  136.39
# episode: 377, e: 0.05, t: 499, score:  144.26, avg score:  133.88
# episode: 378, e: 0.05, t: 360, score: -220.87, avg score:  124.67
# episode: 379, e: 0.05, t: 216, score:  30.09, avg score:  123.49
# episode: 380, e: 0.05, t: 499, score:  36.93, avg score:  120.18
# episode: 381, e: 0.05, t: 414, score:  221.85, avg score:  124.15
# episode: 382, e: 0.05, t: 251, score:  284.68, avg score:  127.86
# episode: 383, e: 0.05, t: 403, score:  154.71, avg score:  129.43
# episode: 384, e: 0.05, t: 287, score:  28.17, avg score:  125.01
# episode: 385, e: 0.05, t: 74, score: -19.33, avg score:  119.65
# episode: 386, e: 0.05, t: 290, score:  25.04, avg score:  117.91
# episode: 387, e: 0.05, t: 345, score:  257.05, avg score:  118.37
# episode: 388, e: 0.05, t: 86, score:  39.24, avg score:  116.85
# episode: 389, e: 0.05, t: 335, score:  257.35, avg score:  116.98
# episode: 390, e: 0.05, t: 383, score:  174.51, avg score:  119.23
# episode: 391, e: 0.05, t: 499, score:  106.58, avg score:  120.72
# episode: 392, e: 0.05, t: 351, score:  247.82, avg score:  119.63
# episode: 393, e: 0.05, t: 330, score: -26.08, avg score:  113.74
# episode: 394, e: 0.05, t: 445, score: -211.24, avg score:  104.02
# episode: 395, e: 0.05, t: 499, score: -30.83, avg score:  97.90
# episode: 396, e: 0.05, t: 252, score: -40.16, avg score:  97.13
# episode: 397, e: 0.05, t: 499, score: -66.77, avg score:  90.50
# episode: 398, e: 0.05, t: 410, score: -74.76, avg score:  85.57
# episode: 399, e: 0.05, t: 133, score:  2.41, avg score:  85.43
# episode: 400, e: 0.05, t: 368, score:  266.01, avg score:  89.24
# episode: 401, e: 0.05, t: 286, score:  300.13, avg score:  94.70
# episode: 402, e: 0.05, t: 299, score:  298.72, avg score:  95.53
# episode: 403, e: 0.05, t: 311, score:  199.23, avg score:  99.96
# episode: 404, e: 0.05, t: 352, score:  231.64, avg score:  98.88
# episode: 405, e: 0.05, t: 272, score:  235.76, avg score:  102.51
# episode: 406, e: 0.05, t: 374, score:  248.89, avg score:  106.00
# episode: 407, e: 0.05, t: 499, score:  106.91, avg score:  103.52
# episode: 408, e: 0.05, t: 276, score:  283.34, avg score:  103.21
# episode: 409, e: 0.05, t: 375, score:  259.26, avg score:  106.44
# episode: 410, e: 0.05, t: 295, score:  224.20, avg score:  107.03
# episode: 411, e: 0.05, t: 499, score: -34.42, avg score:  104.71
# episode: 412, e: 0.05, t: 217, score:  248.82, avg score:  108.25
# episode: 413, e: 0.05, t: 100, score:  8.10, avg score:  104.13
# episode: 414, e: 0.05, t: 499, score: -26.77, avg score:  103.52
# episode: 415, e: 0.05, t: 107, score:  71.55, avg score:  104.56
# episode: 416, e: 0.05, t: 308, score:  256.91, avg score:  108.65
# episode: 417, e: 0.05, t: 482, score:  190.19, avg score:  106.73
# episode: 418, e: 0.05, t: 499, score:  39.53, avg score:  102.24
# episode: 419, e: 0.05, t: 499, score: -81.86, avg score:  100.17
# episode: 420, e: 0.05, t: 499, score: -11.22, avg score:  101.03
# episode: 421, e: 0.05, t: 263, score:  244.77, avg score:  106.59
# episode: 422, e: 0.05, t: 478, score:  204.38, avg score:  111.14
# episode: 423, e: 0.05, t: 499, score:  45.19, avg score:  106.51
# episode: 424, e: 0.05, t: 253, score:  254.40, avg score:  110.81
# episode: 425, e: 0.05, t: 161, score: -69.27, avg score:  105.35
# episode: 426, e: 0.05, t: 263, score:  284.58, avg score:  111.99
# episode: 427, e: 0.05, t: 499, score: -4.08, avg score:  109.03
# episode: 428, e: 0.05, t: 317, score:  294.62, avg score:  119.34
# episode: 429, e: 0.05, t: 499, score: -41.72, avg score:  117.90
# episode: 430, e: 0.05, t: 274, score:  266.36, avg score:  122.49
# episode: 431, e: 0.05, t: 348, score:  266.50, avg score:  123.38
# episode: 432, e: 0.05, t: 499, score:  38.04, avg score:  118.45
# episode: 433, e: 0.05, t: 166, score:  256.82, avg score:  120.49
# episode: 434, e: 0.05, t: 499, score:  81.21, avg score:  121.55
# episode: 435, e: 0.05, t: 287, score:  263.37, avg score:  127.21
# episode: 436, e: 0.05, t: 499, score:  94.84, avg score:  128.60
# episode: 437, e: 0.05, t: 272, score:  255.77, avg score:  128.58
# episode: 438, e: 0.05, t: 499, score:  151.35, avg score:  130.82
# episode: 439, e: 0.05, t: 499, score:  98.23, avg score:  127.64
# episode: 440, e: 0.05, t: 363, score:  257.92, avg score:  129.30
# episode: 441, e: 0.05, t: 200, score:  283.46, avg score:  132.84
# episode: 442, e: 0.05, t: 499, score:  142.29, avg score:  130.73
# episode: 443, e: 0.05, t: 451, score:  255.48, avg score:  136.36
# episode: 444, e: 0.05, t: 288, score:  300.59, avg score:  146.60
# episode: 445, e: 0.05, t: 201, score:  262.89, avg score:  152.47
# episode: 446, e: 0.05, t: 499, score:  62.96, avg score:  154.54
# episode: 447, e: 0.05, t: 403, score:  235.49, avg score:  160.58
# episode: 448, e: 0.05, t: 302, score:  284.41, avg score:  167.76
# episode: 449, e: 0.05, t: 313, score:  266.59, avg score:  173.05
# episode: 450, e: 0.05, t: 499, score:  89.69, avg score:  169.52
# episode: 451, e: 0.05, t: 307, score: -211.48, avg score:  159.29
# episode: 452, e: 0.05, t: 407, score:  235.33, avg score:  158.02
# episode: 453, e: 0.05, t: 400, score:  271.51, avg score:  159.47
# episode: 454, e: 0.05, t: 310, score:  228.20, avg score:  159.40
# episode: 455, e: 0.05, t: 499, score:  64.96, avg score:  155.98
# episode: 456, e: 0.05, t: 306, score:  230.10, avg score:  155.61
# episode: 457, e: 0.05, t: 379, score:  218.91, avg score:  157.85
# episode: 458, e: 0.05, t: 335, score:  273.42, avg score:  157.65
# episode: 459, e: 0.05, t: 288, score:  250.48, avg score:  157.47
# episode: 460, e: 0.05, t: 356, score:  293.74, avg score:  158.86
# episode: 461, e: 0.05, t: 201, score:  275.94, avg score:  165.07
# episode: 462, e: 0.05, t: 497, score:  263.08, avg score:  165.35
# episode: 463, e: 0.05, t: 392, score:  246.76, avg score:  170.13
# episode: 464, e: 0.05, t: 400, score:  202.36, avg score:  174.71
# episode: 465, e: 0.05, t: 99, score:  37.67, avg score:  174.03
# episode: 466, e: 0.05, t: 159, score: -17.04, avg score:  168.55
# episode: 467, e: 0.05, t: 232, score:  285.62, avg score:  170.46
# episode: 468, e: 0.05, t: 297, score:  39.44, avg score:  170.46
# episode: 469, e: 0.05, t: 499, score:  130.25, avg score:  174.70
# episode: 470, e: 0.05, t: 82, score: -47.83, avg score:  173.97
# episode: 471, e: 0.05, t: 287, score: -78.55, avg score:  167.50
# episode: 472, e: 0.05, t: 108, score:  8.41, avg score:  163.59
# episode: 473, e: 0.05, t: 189, score:  279.11, avg score:  168.26
# episode: 474, e: 0.05, t: 170, score:  30.21, avg score:  163.78
# episode: 475, e: 0.05, t: 499, score:  90.96, avg score:  166.98
# episode: 476, e: 0.05, t: 221, score:  191.85, avg score:  165.13
# episode: 477, e: 0.05, t: 499, score:  46.59, avg score:  166.14
# episode: 478, e: 0.05, t: 209, score:  216.87, avg score:  164.59
# episode: 479, e: 0.05, t: 311, score: -232.78, avg score:  160.77
# episode: 480, e: 0.05, t: 377, score:  247.53, avg score:  160.39
# episode: 481, e: 0.05, t: 254, score:  208.36, avg score:  159.23
# episode: 482, e: 0.05, t: 248, score:  54.74, avg score:  159.56
# episode: 483, e: 0.05, t: 210, score:  226.39, avg score:  158.95
# episode: 484, e: 0.05, t: 307, score:  260.50, avg score:  162.54
# episode: 485, e: 0.05, t: 203, score:  205.73, avg score:  161.39
# episode: 486, e: 0.05, t: 117, score:  28.43, avg score:  160.06
# episode: 487, e: 0.05, t: 170, score:  282.99, avg score:  160.60
# episode: 488, e: 0.05, t: 256, score:  245.32, avg score:  162.48
# episode: 489, e: 0.05, t: 252, score:  264.50, avg score:  165.81
# episode: 490, e: 0.05, t: 139, score: -12.02, avg score:  160.41
# episode: 491, e: 0.05, t: 90, score: -21.68, avg score:  154.30
# episode: 492, e: 0.05, t: 170, score:  10.51, avg score:  151.67
# episode: 493, e: 0.05, t: 130, score:  31.47, avg score:  147.19
# episode: 494, e: 0.05, t: 499, score:  151.48, avg score:  144.21
# episode: 495, e: 0.05, t: 317, score:  202.54, avg score:  143.00
# episode: 496, e: 0.05, t: 180, score: -44.05, avg score:  140.86
# episode: 497, e: 0.05, t: 188, score:  242.02, avg score:  140.99
# episode: 498, e: 0.05, t: 282, score:  220.67, avg score:  139.72
# episode: 499, e: 0.05, t: 364, score:  217.77, avg score:  138.74
# episode: 500, e: 0.05, t: 381, score:  240.90, avg score:  141.76
# episode: 501, e: 0.05, t: 380, score:  205.79, avg score:  150.11
# episode: 502, e: 0.05, t: 250, score:  244.35, avg score:  150.29
# episode: 503, e: 0.05, t: 279, score:  255.85, avg score:  149.98
# episode: 504, e: 0.05, t: 80, score:  40.32, avg score:  146.22
# episode: 505, e: 0.05, t: 372, score: -45.85, avg score:  144.00
# episode: 506, e: 0.05, t: 226, score:  223.83, avg score:  143.88
# episode: 507, e: 0.05, t: 164, score: -26.14, avg score:  138.98
# episode: 508, e: 0.05, t: 292, score: -27.02, avg score:  132.97
# episode: 509, e: 0.05, t: 184, score:  242.04, avg score:  132.80
# episode: 510, e: 0.05, t: 283, score:  234.47, avg score:  131.61
# episode: 511, e: 0.05, t: 499, score:  117.47, avg score:  128.44
# episode: 512, e: 0.05, t: 335, score:  271.02, avg score:  128.60
# episode: 513, e: 0.05, t: 279, score:  210.86, avg score:  127.88
# episode: 514, e: 0.05, t: 425, score:  243.70, avg score:  128.71
# episode: 515, e: 0.05, t: 212, score: -1.47, avg score:  127.93
# episode: 516, e: 0.05, t: 463, score:  246.85, avg score:  133.21
# episode: 517, e: 0.05, t: 257, score:  27.83, avg score:  128.05
# episode: 518, e: 0.05, t: 178, score: -19.79, avg score:  126.87
# episode: 519, e: 0.05, t: 360, score:  270.35, avg score:  129.67
# episode: 520, e: 0.05, t: 148, score:  9.69, avg score:  130.82
# episode: 521, e: 0.05, t: 142, score: -52.40, avg score:  131.34
# episode: 522, e: 0.05, t: 499, score:  129.09, avg score:  133.75
# episode: 523, e: 0.05, t: 446, score:  251.80, avg score:  133.21
# episode: 524, e: 0.05, t: 381, score: -2.16, avg score:  132.56
# episode: 525, e: 0.05, t: 97, score:  12.52, avg score:  130.99
# episode: 526, e: 0.05, t: 220, score:  170.77, avg score:  130.57
# episode: 527, e: 0.05, t: 254, score:  155.74, avg score:  132.75
# episode: 528, e: 0.05, t: 245, score:  218.67, avg score:  132.79
# episode: 529, e: 0.05, t: 259, score:  254.93, avg score:  142.54
# episode: 530, e: 0.05, t: 499, score:  149.65, avg score:  140.59
# episode: 531, e: 0.05, t: 499, score:  100.26, avg score:  138.42
# episode: 532, e: 0.05, t: 322, score:  250.09, avg score:  142.33
# episode: 533, e: 0.05, t: 284, score:  225.32, avg score:  142.31
# episode: 534, e: 0.05, t: 372, score:  215.22, avg score:  141.40
# episode: 535, e: 0.05, t: 363, score:  195.13, avg score:  141.19
# episode: 536, e: 0.05, t: 221, score:  206.00, avg score:  144.74
# episode: 537, e: 0.05, t: 139, score:  11.88, avg score:  139.32
# episode: 538, e: 0.05, t: 492, score:  252.99, avg score:  139.48
# episode: 539, e: 0.05, t: 275, score:  215.07, avg score:  138.49
# episode: 540, e: 0.05, t: 350, score:  229.30, avg score:  143.31
# episode: 541, e: 0.05, t: 220, score:  226.58, avg score:  148.28
# episode: 542, e: 0.05, t: 335, score:  233.95, avg score:  152.75
# episode: 543, e: 0.05, t: 255, score:  256.49, avg score:  157.25
# episode: 544, e: 0.05, t: 499, score:  121.36, avg score:  156.65
# episode: 545, e: 0.05, t: 499, score:  95.29, avg score:  154.50
# episode: 546, e: 0.05, t: 105, score: -22.03, avg score:  154.94
# episode: 547, e: 0.05, t: 264, score:  242.15, avg score:  154.94
# episode: 548, e: 0.05, t: 309, score:  260.13, avg score:  155.73
# episode: 549, e: 0.05, t: 245, score:  244.89, avg score:  156.28
# episode: 550, e: 0.05, t: 304, score:  270.62, avg score:  156.87
# episode: 551, e: 0.05, t: 289, score:  249.84, avg score:  157.75
# episode: 552, e: 0.05, t: 233, score:  230.39, avg score:  157.47
# episode: 553, e: 0.05, t: 151, score:  35.86, avg score:  153.07
# episode: 554, e: 0.05, t: 265, score:  240.56, avg score:  157.08
# episode: 555, e: 0.05, t: 234, score:  230.31, avg score:  162.60
# episode: 556, e: 0.05, t: 93, score: -11.62, avg score:  157.89
# episode: 557, e: 0.05, t: 168, score:  211.15, avg score:  162.64
# episode: 558, e: 0.05, t: 131, score: -29.69, avg score:  162.58
# episode: 559, e: 0.05, t: 256, score:  252.43, avg score:  162.79
# episode: 560, e: 0.05, t: 499, score:  128.41, avg score:  160.67
# episode: 561, e: 0.05, t: 346, score:  226.25, avg score:  162.85
# episode: 562, e: 0.05, t: 219, score:  301.50, avg score:  163.45
# episode: 563, e: 0.05, t: 70, score: -118.21, avg score:  156.87
# episode: 564, e: 0.05, t: 217, score:  219.81, avg score:  156.40
# episode: 565, e: 0.05, t: 178, score:  214.78, avg score:  160.72
# episode: 566, e: 0.05, t: 130, score:  10.17, avg score:  155.99
# episode: 567, e: 0.05, t: 95, score: -93.76, avg score:  153.55
# episode: 568, e: 0.05, t: 499, score:  131.57, avg score:  156.58
# episode: 569, e: 0.05, t: 267, score:  261.54, avg score:  156.41
# episode: 570, e: 0.05, t: 193, score:  10.73, avg score:  156.43
# episode: 571, e: 0.05, t: 365, score:  284.52, avg score:  163.17
# episode: 572, e: 0.05, t: 276, score:  299.22, avg score:  166.57
# episode: 573, e: 0.05, t: 321, score:  252.12, avg score:  166.57
# episode: 574, e: 0.05, t: 208, score:  272.35, avg score:  172.06
# episode: 575, e: 0.05, t: 224, score:  297.74, avg score:  177.77
# episode: 576, e: 0.05, t: 385, score:  268.65, avg score:  179.73
# episode: 577, e: 0.05, t: 278, score:  249.92, avg score:  181.61
# episode: 578, e: 0.05, t: 255, score:  281.86, avg score:  182.87
# episode: 579, e: 0.05, t: 209, score:  24.97, avg score:  178.27
# episode: 580, e: 0.05, t: 302, score:  255.10, avg score:  180.38
# episode: 581, e: 0.05, t: 235, score:  264.32, avg score:  183.66
# episode: 582, e: 0.05, t: 333, score:  208.53, avg score:  182.83
# episode: 583, e: 0.05, t: 167, score:  24.64, avg score:  178.82
# episode: 584, e: 0.05, t: 499, score:  110.26, avg score:  176.72
# episode: 585, e: 0.05, t: 222, score:  241.95, avg score:  177.66
# episode: 586, e: 0.05, t: 382, score:  220.05, avg score:  177.94
# episode: 587, e: 0.05, t: 256, score:  281.92, avg score:  183.34
# episode: 588, e: 0.05, t: 266, score:  269.78, avg score:  183.67
# episode: 589, e: 0.05, t: 113, score:  15.87, avg score:  179.69
# episode: 590, e: 0.05, t: 318, score:  246.79, avg score:  180.04
# episode: 591, e: 0.05, t: 214, score:  259.97, avg score:  180.71
# episode: 592, e: 0.05, t: 499, score:  155.51, avg score:  179.14
# episode: 593, e: 0.05, t: 346, score:  264.61, avg score:  179.30
# episode: 594, e: 0.05, t: 197, score:  301.51, avg score:  182.90
# episode: 595, e: 0.05, t: 262, score:  255.00, avg score:  186.10
# episode: 596, e: 0.05, t: 431, score:  255.10, avg score:  191.64
# episode: 597, e: 0.05, t: 97, score: -4.91, avg score:  186.70
# episode: 598, e: 0.05, t: 191, score:  244.29, avg score:  186.38
# episode: 599, e: 0.05, t: 423, score:  246.88, avg score:  186.42
# episode: 600, e: 0.05, t: 272, score:  278.47, avg score:  186.58
# episode: 601, e: 0.05, t: 181, score:  274.12, avg score:  187.07
# episode: 602, e: 0.05, t: 289, score:  260.10, avg score:  187.66
# episode: 603, e: 0.05, t: 270, score:  283.49, avg score:  192.61
# episode: 604, e: 0.05, t: 331, score:  250.51, avg score:  192.81
# episode: 605, e: 0.05, t: 499, score:  66.12, avg score:  189.53
# episode: 606, e: 0.05, t: 413, score:  233.31, avg score:  194.43
# episode: 607, e: 0.05, t: 252, score:  273.43, avg score:  195.67
# episode: 608, e: 0.05, t: 339, score:  235.93, avg score:  200.98
